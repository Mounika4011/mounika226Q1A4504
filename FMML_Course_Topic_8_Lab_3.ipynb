# %% [markdown]
# <a href="https://colab.research.google.com/github/Mounika4011/mounika226Q1A4504/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-29 06:57:20--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  75.6MB/s    in 0.9s
#
# 2024-03-29 06:57:22 (75.6 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22909  1710.07939v1  The characteristics (or numerical patterns) of...  stat
# 3641   1604.01219v1  Researchers often summarize their work in the ...    cs
# 10691   1212.0388v1  Most network-based protein (or gene) function ...  stat
# 13684  1612.06093v2  One of the major distinguishing features of th...    cs
# 9550   1707.03981v1  Automatic photo aesthetic assessment is a chal...    cs
# ...             ...                                                ...   ...
# 32550   1312.4209v1  In this article we propose feature graph archi...    cs
# 34030   1205.1975v1  In infrastructure-less highly dynamic networks...    cs
# 4370   1608.04664v2  We address the task of simultaneous feature fu...  stat
# 12648   1301.3461v7  In this paper we present a modification to a l...    cs
# 19035   1301.7366v1  Given an undirected graph G or hypergraph X mo...    cs
#
#                                                    title  year  \
# 22909  Elliptical modeling and pattern analysis for p...  2017
# 3641   Learning to Generate Posters of Scientific Papers  2016
# 10691  Hypergraph and protein function prediction wit...  2012
# 13684  Transfer Learning based Dynamic Multiobjective...  2016
# 9550      Learning Photography Aesthetics with Deep CNNs  2017
# ...                                                  ...   ...
# 32550                        Feature Graph Architectures  2013
# 34030  Expressivity of Time-Varying Graphs and the Po...  2012
# 4370   Variational Gaussian Process Auto-Encoder for ...  2016
# 12648                            Factorized Topic Models  2013
# 19035  Marginalizing in Undirected Graph and Hypergra...  2013
#
#                                                 keywords
# 22909  [characteristics, numerical, transform, pertur...
# 3641   [researchers, summarize, efficient, scientific...
# 10691  [prediction, assumption, relationship, informa...
# 13684  [distinguishing, multiobjective, optimization,...
# 9550   [automatic, aesthetic, assessment, challenging...
# ...                                                  ...
# 32550  [architectures, employing, structured, initial...
# 34030  [infrastructure, computing, performing, challe...
# 4370   [simultaneous, particular, introduce, responsi...
# 12648  [modification, supervision, factorized, repres...
# 19035  [undirected, hypergraph, variables, introduce,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22909    [characteristics, numerical, transform, pertur...
# 3641     [researchers, summarize, efficient, scientific...
# 10691    [prediction, assumption, relationship, informa...
# 13684    [distinguishing, multiobjective, optimization,...
# 9550     [automatic, aesthetic, assessment, challenging...
#                                ...
# 22118    [semiparametric, exponential, graphical, dimen...
# 6644     [activities, preference, comparisons, offering...
# 11483    [algorithms, dimensional, representation, dime...
# 17700    [structure, individuals, represent, cognitive,...
# 34063    [political, interactions, parliament, consider...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8717 words.
# Out of those 4572 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f85a1f44-588b-4733-963f-587bb06c7cc2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f85a1f44-588b-4733-963f-587bb06c7cc2")) {                    Plotly.newPlot(                        "f85a1f44-588b-4733-963f-587bb06c7cc2",                        [{"x":["transforms","component","classification","parametric","empirical","performance","significantly","interference","evaluated","transform","difficulty","nonlinear","accommodate","transformation","techniques","characteristics","applications","separation","associated","differences","dimensional","biological","confirmed","protection","degradation","intrusion","assumptions","numerical","elliptical","principal","dimensionality","corresponding","inverting","perturbation","statistical","technique","reduction","cognitive","qualitative","synthesized","framework","composition","summarize","exhaustively","quantitative","generating","efficient","including","scientific","attributes","specifically","informative","graphical","researchers","challenging","effectiveness","aesthetic","consuming","functional","experiment","information","overcoming","constructed","symmetric","supervised","expression","relationship","assumption","prediction","hypergraph","normalized","laplacian","represent","functions","introduced","optimization","promising","integrates","algorithmic","challenge","estimation","algorithm","technology","construct","experiences","modifications","distributed","distinguishing","objectives","solutions","integration","incorporate","regularity","exploiting","identically","experience","population","benchmark","experimental","evolutionary","approaches","nondominated","extensive","multiobjective","independent","development","distribution","algorithms","interpretation","contribute","different","automatic","providing","assessment","activation","visualization","diversity","convolution","computational","aesthetics","gradients","artificial","highlight","visualizations","understand","photograph","representation","important","intelligence","propagation","photography","complexity","multitask","recognition","dependencies","reparameterization","reinforcement","successfully","direction","convergence","sensitive","modelling","usefulness","decouples","conditioning","minibatch","introduce","accelerate","permitting","recurrent","generative","stochastic","normalization","demonstrate","certificate","technical","conditional","optimality","additional","objective","generalized","discussed","investigation","character","translation","evaluation","morphological","extrinsic","morphology","structure","parameters","languages","granularity","maintaining","representations","empirically","architecture","synthesize","associations","observation","discovery","variation","invariant","supervisory","strengths","comparing","resurgence","detection","encourage","underlying","perturbations","factorial","constrain","connected","coefficients","encodings","unsupervised","observations","constraints","facilitates"],"y":[15,114,481,43,138,913,282,6,156,59,48,55,9,59,378,82,413,26,106,58,159,39,14,8,23,7,74,69,1,40,51,150,1,18,161,254,108,41,55,15,540,29,16,4,60,100,368,243,31,72,146,44,58,72,255,225,8,32,27,87,662,8,70,22,216,53,76,66,234,3,28,17,123,208,131,288,113,27,42,164,215,786,63,86,13,15,91,9,33,147,51,77,11,82,2,37,61,204,343,63,398,4,145,6,147,114,209,573,51,33,773,174,113,49,36,26,41,42,272,2,26,142,30,9,85,3,344,325,98,74,6,237,11,337,67,1,117,87,58,94,42,46,29,2,11,1,331,23,4,151,106,129,32,543,3,35,105,25,138,161,79,58,26,64,122,245,26,4,15,314,243,116,11,34,234,68,254,16,11,56,41,70,67,4,14,72,4,332,16,129,19,2,13,71,40,9,159,77,154,18],"type":"bar"},{"x":["transforms","component","classification","parametric","empi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4572,), (4572, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8133333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>symbolic</span> <span style=''>algebra</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>of</span> <span style=''>expected</span> <span style='background-color:rgba(0, 255, 0, 0.8000000000000002);'>utilities</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiplicative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influence</span> <span style=''>diagrams</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Influence</span> <span style=''>diagrams</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>compact</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333332);'>graphical</span> <span style='background-color:rgba(0, 255, 0, 0.3516699410609037);'>representation</span> <span style=''>of</span> <span style=''>decision</span> <span style=''>problems</span> <span style=''>Several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>the</span> <span style=''>quick</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>of</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style=''>expected</span> <span style='background-color:rgba(0, 255, 0, 0.8000000000000002);'>utilities</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>However</span> <span style=''>often</span> <span style=''>they</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>a</span> <span style=''>full</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quantification</span> <span style=''>of</span> <span style=''>both</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainties</span> <span style=''>and</span> <span style=''>utility</span> <span style=''>values</span> <span style=''>For</span> <span style=''>problems</span> <span style=''>where</span> <span style=''>all</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3679012345679012);'>variables</span> <span style=''>and</span> <span style=''>decision</span> <span style=''>spaces</span> <span style=''>are</span> <span style=''>finite</span> <span style=''>and</span> <span style=''>discrete</span> <span style=''>here</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>symbolic</span> <span style=''>way</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>calculate</span> <span style=''>the</span> <span style=''>expected</span> <span style='background-color:rgba(0, 255, 0, 0.8000000000000002);'>utilities</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influence</span> <span style=''>diagrams</span> <span style=''>that</span> <span style=''>does</span> <span style=''>not</span> <span style=''>require</span> <span style=''>a</span> <span style=''>full</span> <span style='background-color:rgba(255, 0, 0, 0.4869888475836432);'>numerical</span> <span style='background-color:rgba(0, 255, 0, 0.3516699410609037);'>representation</span> <span style=''>Within</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>expected</span> <span style='background-color:rgba(0, 255, 0, 0.8000000000000002);'>utilities</span> <span style='background-color:rgba(0, 255, 0, 0.411764705882353);'>correspond</span> <span style=''>to</span> <span style=''>families</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>polynomials ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Explanation</span> <span style=''>System</span> <span style=''>Latest</span> <span style=''>Updates</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Extensions</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanation</span> <span style=''>system</span> <span style=''>(MES)</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explaining</span> <span style=''>the</span> <span style=''>output</span> <span style=''>of</span> <span style=''>black</span> <span style=''>box</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>describes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensions</span> <span style=''>to</span> <span style=''>Turner</span> <span style=''>(2015)</span> <span style=''>which</span> <span style=''>is</span> <span style=''>referred</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequently</span> <span style=''>in</span> <span style=''>the</span> <span style=''>text</span> <span style=''>We</span> <span style=''>use</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivating</span> <span style=''>example</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>trained</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>fraud</span> <span style=''>in</span> <span style=''>a</span> <span style=''>credit</span> <span style=''>card</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transaction</span> <span style=''>history</span> <span style=''>The</span> <span style=''>key</span> <span style=''>aspect</span> <span style=''>is</span> <span style=''>that</span> <span style=''>we</span> <span style=''>provide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explanations</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicable</span> <span style=''>to</span> <span style=''>a</span> <span style=''>single</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>rather</span> <span style=''>than</span> <span style=''>provide</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>We</span> <span style=''>focus</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explaining</span> <span style=''>positive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>(alerts)</span> <span style=''>However</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presented</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>is</span> <span style=''>symmetrically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicable</span> <span style=''>to</span> <span style=''>negative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Active</span> <span style=''>Learning</span> <span style=''>Using</span> <span style=''>Smooth</span> <span style=''>Relative</span> <span style=''>Regret</span> <span style='background-color:rgba(255, 0, 0, 0.39495798319327724);'>Approximations</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Applications</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>disagreement</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coefficient</span> <span style=''>of</span> <span style=''>Hanneke</span> <span style=''>has</span> <span style=''>become</span> <span style=''>a</span> <span style=''>central</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invariant</span> <span style=''>in</span> <span style=''>proving</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>rates</span> <span style=''>It</span> <span style=''>has</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>in</span> <span style=''>various</span> <span style=''>ways</span> <span style=''>that</span> <span style=''>a</span> <span style=''>concept</span> <span style=''>class</span> <span style=''>with</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>together</span> <span style=''>with</span> <span style=''>a</span> <span style=''>bound</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>disagreement</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coefficient</span> <span style=''>at</span> <span style=''>an</span> <span style=''>optimal</span> <span style=''>solution</span> <span style=''>allows</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>rates</span> <span style=''>that</span> <span style=''>are</span> <span style=''>superior</span> <span style=''>to</span> <span style=''>passive</span> <span style=''>learning</span> <span style=''>ones</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.362114537444934);'>different</span> <span style=''>tool</span> <span style=''>for</span> <span style=''>pool</span> <span style=''>based</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>which</span> <span style=''>follows</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>existence</span> <span style=''>of</span> <span style=''>a</span> <span style=''>certain</span> <span style=''>uniform</span> <span style=''>version</span> <span style=''>of</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>disagreement</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coefficient</span> <span style=''>but</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>it</span> <span style=''>In</span> <span style=''>fact</span> <span style=''>we</span> <span style=''>present</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significant</span> <span style=''>interest</span> <span style=''>for</span> <span style=''>which</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>allows</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>nontrivial</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>bounds</span> <span style=''>However</span> <span style=''>any</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Making</span> <span style=''>Tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Ensembles</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Interpretable</span> <span style=''>A</span> <span style=''>Bayesian</span> <span style=''>Model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>Approach</span> <br/><br/><span style=''>Tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ensembles</span> <span style=''>such</span> <span style=''>as</span> <span style=''>random</span> <span style=''>forests</span> <span style=''>and</span> <span style=''>boosted</span> <span style=''>trees</span> <span style=''>are</span> <span style=''>renowned</span> <span style=''>for</span> <span style=''>their</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>However</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>critically</span> <span style=''>limited</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>enormous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>In</span> <span style=''>this</span> <span style=''>study</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>method</span> <span style=''>to</span> <span style=''>make</span> <span style=''>a</span> <span style=''>complex</span> <span style=''>tree</span> <span style=''>ensemble</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simplifying</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Specifically</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formalize</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simplification</span> <span style=''>of</span> <span style=''>tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ensembles</span> <span style=''>as</span> <span style=''>a</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>problem</span> <span style=''>Given</span> <span style=''>a</span> <span style=''>complex</span> <span style=''>tree</span> <span style=''>ensemble</span> <span style=''>we</span> <span style=''>aim</span> <span style=''>at</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>obtaining</span> <span style=''>the</span> <span style=''>simplest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essentially</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>the</span> <span style=''>original</span> <span style=''>one</span> <span style=''>To</span> <span style=''>this</span> <span style=''>end</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simplified</span> <span style=''>model</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maintaining</span> <span style=''>the</span> <span style='background- ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.09985785358919687)
# 	experimental (0.12189054726368159)
# 	segmentation (0.06645344705046198)
# 	information (0.23525230987917556)
# 	architecture (0.09026297085998579)
# 	knowledge (0.13503909026297087)
# 	detection (0.11798152096659559)
# 	recognition (0.11975835110163469)
# 	convolutional (0.12864250177683015)
# 	different (0.27469793887704336)
#
# Some Statistics words are:
# 	convergence (0.12185297079556898)
# 	variables (0.13947633434038267)
# 	estimation (0.17371601208459214)
# 	theoretical (0.14954682779456194)
# 	statistical (0.15659617321248742)
# 	distribution (0.18328298086606243)
# 	algorithm (0.39224572004028196)
# 	inference (0.19687814702920442)
# 	regression (0.17371601208459214)
# 	dimensional (0.19184290030211482)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2a3dee30-4096-402e-9167-faa43706dfb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a3dee30-4096-402e-9167-faa43706dfb3")) {                    Plotly.newPlot(                        "2a3dee30-4096-402e-9167-faa43706dfb3",                        [{"x":["transforms","component","classification","parametric","empirical","performance","significantly","interference","evaluated","transform","difficulty","nonlinear","accommodate","transformation","techniques","characteristics","applications","separation","associated","differences","dimensional","biological","confirmed","protection","degradation","intrusion","assumptions","numerical","elliptical","principal","dimensionality","corresponding","inverting","perturbation","statistical","technique","reduction","cognitive","qualitative","synthesized","framework","composition","summarize","exhaustively","quantitative","generating","efficient","including","scientific","attributes","specifically","informative","graphical","researchers","challenging","effectiveness","aesthetic","consuming","functional","experiment","information","overcoming","constructed","symmetric","supervised","expression","relationship","assumption","prediction","hypergraph","normalized","laplacian","represent","functions","introduced","optimization","promising","integrates","algorithmic","challenge","estimation","algorithm","technology","construct","experiences","modifications","distributed","distinguishing","objectives","solutions","integration","incorporate","regularity","exploiting","identically","experience","population","benchmark","experimental","evolutionary","approaches","nondominated","extensive","multiobjective","independent","development","distribution","algorithms","interpretation","contribute","different","automatic","providing","assessment","activation","visualization","diversity","convolution","computational","aesthetics","gradients","artificial","highlight","visualizations","understand","photograph","representation","important","intelligence","propagation","photography","complexity","multitask","recognition","dependencies","reparameterization","reinforcement","successfully","direction","convergence","sensitive","modelling","usefulness","decouples","conditioning","minibatch","introduce","accelerate","permitting","recurrent","generative","stochastic","normalization","demonstrate","certificate","technical","conditional","optimality","additional","objective","generalized","discussed","investigation","character","translation","evaluation","morphological","extrinsic","morphology","structure","parameters","languages","granularity","maintaining","representations","empirically","architecture","synthesize","associations","observation","discovery","variation","invariant","supervisory","strengths","comparing","resurgence","detection","encourage","underlying","perturbations","factorial","constrain","connected","coefficients","encodings","unsupervised","observations","constraints","facilitates","generation","inductive","environment","dictionaries","presented","comparison","operations","structural","description","implementation","describing","available","sequences","characters","developers","databases","deviation","distinctive","attribute","simultaneously","correlation","indicates","consistent","effective","efficiency","furthermore","obtaining","characterize","perceptual","competing","judgments","attention","similarity","considering","understanding","supervision","sentiment","extraction","community","annotation","prominently","beginning","witnessed","compilation","representative","challenges","dimensions","predicting","prevalence","summarizes","milestones","illustrations","resources","multimedia","simulated","p ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	geological
# 	emphstructured
# 	nutrition
# 	multiparametric
# 	experimenter
# 	cytometry
# 	hermitian
# 	periodicity
# 	fluctuation
# 	multiplied
# 	underestimates
# 	underestimation
# 	necessitate
# 	propensity
# 	seasonality
# 	gaussianity
# 	criticize
# 	overdetermined
# 	streamline
# 	particulars
# Some words which never appear in Statistics papers:
# 	aesthetic
# 	nondominated
# 	multiobjective
# 	photograph
# 	photography
# 	compilation
# 	summarizes
# 	malayalam
# 	simplifications
# 	deformation
# 	syntactic
# 	authenticity
# 	functionalities
# 	neocortex
# 	neocortical
# 	scattering
# 	abstractive
# 	connectionist
# 	relocalization
# 	satisfiability

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0569821472242604e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7691666666666667
